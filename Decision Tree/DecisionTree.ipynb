# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
poke = pd.read_csv("Pokemon.csv")

# %%
p = pd.read_csv("Pokemon.csv")

# %%
p.head()
# Out:
#    Number           Name Type 1  Type 2                    Abilities  HP  Att  \
# 0       1      Bulbasaur  Grass  Poison  ['Chlorophyll', 'Overgrow']  45   49
# 1       2        Ivysaur  Grass  Poison  ['Chlorophyll', 'Overgrow']  60   62
# 2       3       Venusaur  Grass  Poison  ['Chlorophyll', 'Overgrow']  80   82
# 3       3  Mega Venusaur  Grass  Poison                ['Thick Fat']  80  100
# 4       4     Charmander   Fire     NaN     ['Blaze', 'Solar Power']  39   52
#
#    Def  Spa  Spd  ...  Against Bug  Against Rock  Against Ghost  \
# 0   49   65   65  ...          1.0           1.0            1.0
# 1   63   80   80  ...          1.0           1.0            1.0
# 2   83  100  100  ...          1.0           1.0            1.0
# 3  123  122  120  ...          1.0           1.0            1.0
# 4   43   60   50  ...          0.5           2.0            1.0
#
#    Against Dragon  Against Dark Against Steel  Against Fairy  Height  Weight  \
# ...

# %%
p= p[["Name","Type 1","Type 2","HP","Att","Def","Spa","Spd","Height","Weight","BMI","Legendary"]]

# %%
p.columns = ["name","primaryType","secondaryType","hp","attack","defence","spa","speed","height","weight","BMI","legendary"]

# %%
p.head()
# Out:
#             name primaryType secondaryType  hp  attack  defence  spa  speed  \
# 0      Bulbasaur       Grass        Poison  45      49       49   65     65
# 1        Ivysaur       Grass        Poison  60      62       63   80     80
# 2       Venusaur       Grass        Poison  80      82       83  100    100
# 3  Mega Venusaur       Grass        Poison  80     100      123  122    120
# 4     Charmander        Fire           NaN  39      52       43   60     50
#
#    height  weight   BMI  legendary
# 0     0.7     6.9  14.1        0.0
# 1     1.0    13.0  13.0        0.0
# 2     2.0   100.0  25.0        0.0
# 3     2.4   155.5  27.0        0.0
# 4     0.6     8.5  23.6        0.0

# %%
poke.head()
# Out:
#    Number           Name Type 1  Type 2                    Abilities  HP  Att  \
# 0       1      Bulbasaur  Grass  Poison  ['Chlorophyll', 'Overgrow']  45   49
# 1       2        Ivysaur  Grass  Poison  ['Chlorophyll', 'Overgrow']  60   62
# 2       3       Venusaur  Grass  Poison  ['Chlorophyll', 'Overgrow']  80   82
# 3       3  Mega Venusaur  Grass  Poison                ['Thick Fat']  80  100
# 4       4     Charmander   Fire     NaN     ['Blaze', 'Solar Power']  39   52
#
#    Def  Spa  Spd  ...  Against Bug  Against Rock  Against Ghost  \
# 0   49   65   65  ...          1.0           1.0            1.0
# 1   63   80   80  ...          1.0           1.0            1.0
# 2   83  100  100  ...          1.0           1.0            1.0
# 3  123  122  120  ...          1.0           1.0            1.0
# 4   43   60   50  ...          0.5           2.0            1.0
#
#    Against Dragon  Against Dark Against Steel  Against Fairy  Height  Weight  \
# ...

# %%
poke = poke[["Name","Type 1","Type 2","HP","Att","Def","Spa","Spd","Height","Weight","BMI"]]

# %%
poke.head()
# Out:
#             Name Type 1  Type 2  HP  Att  Def  Spa  Spd  Height  Weight   BMI
# 0      Bulbasaur  Grass  Poison  45   49   49   65   65     0.7     6.9  14.1
# 1        Ivysaur  Grass  Poison  60   62   63   80   80     1.0    13.0  13.0
# 2       Venusaur  Grass  Poison  80   82   83  100  100     2.0   100.0  25.0
# 3  Mega Venusaur  Grass  Poison  80  100  123  122  120     2.4   155.5  27.0
# 4     Charmander   Fire     NaN  39   52   43   60   50     0.6     8.5  23.6

# %%
poke.columns = ["name","type1","type2","hp","attack","defence","spa","speed","height","weight","BMI"]

# %%
poke.head()
# Out:
#             name  type1   type2  hp  attack  defence  spa  speed  height  \
# 0      Bulbasaur  Grass  Poison  45      49       49   65     65     0.7
# 1        Ivysaur  Grass  Poison  60      62       63   80     80     1.0
# 2       Venusaur  Grass  Poison  80      82       83  100    100     2.0
# 3  Mega Venusaur  Grass  Poison  80     100      123  122    120     2.4
# 4     Charmander   Fire     NaN  39      52       43   60     50     0.6
#
#    weight   BMI
# 0     6.9  14.1
# 1    13.0  13.0
# 2   100.0  25.0
# 3   155.5  27.0
# 4     8.5  23.6

# %%
poke.rename(columns={'type1':'primaryType','type2':'secondaryType'},inplace=True)

# %%
poke.head()
# Out:
#             name primaryType secondaryType  hp  attack  defence  spa  speed  \
# 0      Bulbasaur       Grass        Poison  45      49       49   65     65
# 1        Ivysaur       Grass        Poison  60      62       63   80     80
# 2       Venusaur       Grass        Poison  80      82       83  100    100
# 3  Mega Venusaur       Grass        Poison  80     100      123  122    120
# 4     Charmander        Fire           NaN  39      52       43   60     50
#
#    height  weight   BMI
# 0     0.7     6.9  14.1
# 1     1.0    13.0  13.0
# 2     2.0   100.0  25.0
# 3     2.4   155.5  27.0
# 4     0.6     8.5  23.6

# %%
poke['primaryType']=='Grass'
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 1027    False
# 1028    False
# 1029    False
# 1030    False
# 1031    False
# Name: primaryType, Length: 1032, dtype: bool

# %%
poke[poke['primaryType']=='Grass']
# Out:
#               name primaryType secondaryType   hp  attack  defence  spa  \
# 0        Bulbasaur       Grass        Poison   45      49       49   65
# 1          Ivysaur       Grass        Poison   60      62       63   80
# 2         Venusaur       Grass        Poison   80      82       83  100
# 3    Mega Venusaur       Grass        Poison   80     100      123  122
# 55          Oddish       Grass        Poison   45      50       55   75
# ..             ...         ...           ...  ...     ...      ...  ...
# 956     Gossifleur       Grass           NaN   40      40       60   40
# 957       Eldegoss       Grass           NaN   60      50       90   80
# 967         Applin       Grass        Dragon   40      40       80   40
# 968        Flapple       Grass        Dragon   70     110       80   95
# 969       Appletun       Grass        Dragon  110      85       80  100
#
#      speed  height  weight   BMI
# 0       65     0.7     6.9  14.1
# 1       80     1.0    13.0  13.0
# ...

# %%
grassPokemon = poke[poke['primaryType']=='Grass']

# %%
grassPokemon.head()
# Out:
#              name primaryType secondaryType  hp  attack  defence  spa  speed  \
# 0       Bulbasaur       Grass        Poison  45      49       49   65     65
# 1         Ivysaur       Grass        Poison  60      62       63   80     80
# 2        Venusaur       Grass        Poison  80      82       83  100    100
# 3   Mega Venusaur       Grass        Poison  80     100      123  122    120
# 55         Oddish       Grass        Poison  45      50       55   75     65
#
#     height  weight   BMI
# 0      0.7     6.9  14.1
# 1      1.0    13.0  13.0
# 2      2.0   100.0  25.0
# 3      2.4   155.5  27.0
# 55     0.5     5.4  21.6

# %%
waterPokemon = poke[poke['primaryType']=='Water']

# %%
waterPokemon.head()
# Out:
#               name primaryType secondaryType  hp  attack  defence  spa  speed  \
# 9         Squirtle       Water           NaN  44      48       65   50     64
# 10       Wartortle       Water           NaN  59      63       80   65     80
# 11       Blastoise       Water           NaN  79      83      100   85    105
# 12  Mega Blastoise       Water           NaN  79     103      120  135    115
# 71         Psyduck       Water           NaN  50      52       48   65     50
#
#     height  weight   BMI
# 9      0.5     9.0  36.0
# 10     1.0    22.5  22.5
# 11     1.6    85.5  33.4
# 12     1.6   101.1  39.5
# 71     0.8    19.6  30.6

# %%
firePokemon = poke[poke['primaryType']=='Fire']

# %%
firePokemon.head()
# Out:
#                name primaryType secondaryType  hp  attack  defence  spa  \
# 4        Charmander        Fire           NaN  39      52       43   60
# 5        Charmeleon        Fire           NaN  58      64       58   80
# 6         Charizard        Fire        Flying  78      84       78  109
# 7  Mega Charizard Y        Fire        Flying  78     104       78  159
# 8  Mega Charizard X        Fire        Dragon  78     130      111  130
#
#    speed  height  weight   BMI
# 4     50     0.6     8.5  23.6
# 5     65     1.1    19.0  15.7
# 6     85     1.7    90.5  31.3
# 7    115     1.7   100.5  34.8
# 8     85     1.7   110.5  38.2

# %%
poke.shape
# Out:
# (1032, 11)

# %%
grassPokemon.shape
# Out:
# (91, 11)

# %%
waterPokemon.shape
# Out:
# (131, 11)

# %%
firePokemon.shape
# Out:
# (64, 11)

# %%
(131+64+64)/1032
# Out:
# 0.250968992248062

# %%
grassPokemon.head()
# Out:
#              name primaryType secondaryType  hp  attack  defence  spa  speed  \
# 0       Bulbasaur       Grass        Poison  45      49       49   65     65
# 1         Ivysaur       Grass        Poison  60      62       63   80     80
# 2        Venusaur       Grass        Poison  80      82       83  100    100
# 3   Mega Venusaur       Grass        Poison  80     100      123  122    120
# 55         Oddish       Grass        Poison  45      50       55   75     65
#
#     height  weight   BMI
# 0      0.7     6.9  14.1
# 1      1.0    13.0  13.0
# 2      2.0   100.0  25.0
# 3      2.4   155.5  27.0
# 55     0.5     5.4  21.6

# %%
sns.histplot(grassPokemon['speed'])
plt.show()

# %%
sns.histplot(grassPokemon['spa'])
plt.show()

# %%
sns.histplot(grassPokemon['defence'])
plt.show()

# %%
grassPokemon.head()
# Out:
#              name primaryType secondaryType  hp  attack  defence  spa  speed  \
# 0       Bulbasaur       Grass        Poison  45      49       49   65     65
# 1         Ivysaur       Grass        Poison  60      62       63   80     80
# 2        Venusaur       Grass        Poison  80      82       83  100    100
# 3   Mega Venusaur       Grass        Poison  80     100      123  122    120
# 55         Oddish       Grass        Poison  45      50       55   75     65
#
#     height  weight   BMI
# 0      0.7     6.9  14.1
# 1      1.0    13.0  13.0
# 2      2.0   100.0  25.0
# 3      2.4   155.5  27.0
# 55     0.5     5.4  21.6

# %%
grassPokemon.describe()
# Out:
#                hp      attack     defence         spa       speed     height  \
# count   91.000000   91.000000   91.000000   91.000000   91.000000  91.000000
# mean    66.736264   74.813187   71.824176   75.043956   70.054945   1.071429
# std     19.585616   29.331027   24.312134   27.077220   22.301650   1.231376
# min     30.000000   27.000000   30.000000   24.000000   30.000000   0.200000
# 25%     50.000000   51.500000   52.500000   55.000000   55.000000   0.400000
# 50%     66.000000   70.000000   70.000000   74.000000   70.000000   0.800000
# 75%     75.000000   99.000000   85.000000   96.000000   85.000000   1.250000
# max    123.000000  181.000000  131.000000  145.000000  129.000000  10.900000
#
#           weight         BMI
# count   91.00000   91.000000
# mean    39.83956   29.809890
# std     65.81630   36.069864
# min      0.10000    1.100000
# 25%      4.75000   13.650000
# 50%     14.00000   25.000000
# 75%     48.00000   32.600000
# max    415.60000  320.600000

# %%
waterPokemon.head()
# Out:
#               name primaryType secondaryType  hp  attack  defence  spa  speed  \
# 9         Squirtle       Water           NaN  44      48       65   50     64
# 10       Wartortle       Water           NaN  59      63       80   65     80
# 11       Blastoise       Water           NaN  79      83      100   85    105
# 12  Mega Blastoise       Water           NaN  79     103      120  135    115
# 71         Psyduck       Water           NaN  50      52       48   65     50
#
#     height  weight   BMI
# 9      0.5     9.0  36.0
# 10     1.0    22.5  22.5
# 11     1.6    85.5  33.4
# 12     1.6   101.1  39.5
# 71     0.8    19.6  30.6

# %%
sns.histplot(waterPokemon["speed"], color = "red")
plt.show()

# %%
waterPokemon.describe()
# Out:
#                hp      attack     defence         spa       speed      height  \
# count  131.000000  131.000000  131.000000  131.000000  131.000000  131.000000
# mean    70.748092   74.923664   73.076336   74.595420   71.389313    1.454962
# std     26.294879   29.171540   28.164522   30.061675   29.625502    1.828628
# min     20.000000   10.000000   20.000000   10.000000   20.000000    0.200000
# 25%     50.000000   54.500000   53.500000   53.000000   50.000000    0.600000
# 50%     70.000000   72.000000   70.000000   70.000000   68.000000    1.000000
# 75%     90.000000   92.000000   90.000000   93.000000   90.000000    1.600000
# max    170.000000  155.000000  180.000000  180.000000  160.000000   14.500000
#
#            weight         BMI
# count  131.000000  131.000000
# mean    59.045038   33.547328
# std     80.040365   31.654414
# min      0.300000    1.200000
# 25%     10.450000   19.400000
# 50%     28.500000   28.000000
# 75%     79.050000   41.050000
# ...

# %%
grassPokemon.describe()
# Out:
#                hp      attack     defence         spa       speed     height  \
# count   91.000000   91.000000   91.000000   91.000000   91.000000  91.000000
# mean    66.736264   74.813187   71.824176   75.043956   70.054945   1.071429
# std     19.585616   29.331027   24.312134   27.077220   22.301650   1.231376
# min     30.000000   27.000000   30.000000   24.000000   30.000000   0.200000
# 25%     50.000000   51.500000   52.500000   55.000000   55.000000   0.400000
# 50%     66.000000   70.000000   70.000000   74.000000   70.000000   0.800000
# 75%     75.000000   99.000000   85.000000   96.000000   85.000000   1.250000
# max    123.000000  181.000000  131.000000  145.000000  129.000000  10.900000
#
#           weight         BMI
# count   91.00000   91.000000
# mean    39.83956   29.809890
# std     65.81630   36.069864
# min      0.10000    1.100000
# 25%      4.75000   13.650000
# 50%     14.00000   25.000000
# 75%     48.00000   32.600000
# max    415.60000  320.600000

# %%
firePokemon.describe()
# Out:
#                hp      attack     defence         spa       speed     height  \
# count   64.000000   64.000000   64.000000   64.000000   64.000000  64.000000
# mean    69.421875   85.640625   68.078125   86.671875   71.312500   1.218750
# std     18.896380   27.605134   24.577900   30.266045   21.883439   0.672563
# min     38.000000   30.000000   37.000000   15.000000   40.000000   0.300000
# 25%     58.000000   64.750000   49.500000   65.000000   53.500000   0.700000
# 50%     67.500000   84.500000   64.000000   83.000000   69.500000   1.050000
# 75%     80.000000  104.000000   78.000000  106.000000   85.000000   1.700000
# max    115.000000  160.000000  140.000000  159.000000  154.000000   3.800000
#
#            weight         BMI
# count   64.000000   64.000000
# mean    66.023438   40.814062
# std     80.256454   42.884159
# min      1.000000    2.000000
# 25%     15.625000   23.575000
# 50%     34.500000   31.100000
# 75%     84.875000   49.250000
# ...

# %%
poke.head()
# Out:
#             name primaryType secondaryType  hp  attack  defence  spa  speed  \
# 0      Bulbasaur       Grass        Poison  45      49       49   65     65
# 1        Ivysaur       Grass        Poison  60      62       63   80     80
# 2       Venusaur       Grass        Poison  80      82       83  100    100
# 3  Mega Venusaur       Grass        Poison  80     100      123  122    120
# 4     Charmander        Fire           NaN  39      52       43   60     50
#
#    height  weight   BMI
# 0     0.7     6.9  14.1
# 1     1.0    13.0  13.0
# 2     2.0   100.0  25.0
# 3     2.4   155.5  27.0
# 4     0.6     8.5  23.6

# %%
poke["secondaryType"].value_counts()
# Out:
# Flying      112
# Psychic      42
# Fairy        41
# Ground       39
# Poison       37
# Steel        35
# Fighting     31
# Dragon       30
# Grass        28
# Ghost        27
# Dark         26
# Water        20
# Ice          18
# Fire         17
# Rock         15
# Electric     11
# Normal       10
# Bug           9
# Name: secondaryType, dtype: int64

# %%
poke["primaryType"].value_counts()
# Out:
# Water       131
# Normal      114
# Grass        91
# Bug          81
# Psychic      77
# Fire         64
# Rock         59
# Electric     59
# Dark         46
# Fighting     42
# Dragon       42
# Ghost        41
# Ground       41
# Poison       40
# Ice          38
# Steel        36
# Fairy        22
# Flying        8
# Name: primaryType, dtype: int64

# %%
poke.head()
# Out:
#             name primaryType secondaryType  hp  attack  defence  spa  speed  \
# 0      Bulbasaur       Grass        Poison  45      49       49   65     65
# 1        Ivysaur       Grass        Poison  60      62       63   80     80
# 2       Venusaur       Grass        Poison  80      82       83  100    100
# 3  Mega Venusaur       Grass        Poison  80     100      123  122    120
# 4     Charmander        Fire           NaN  39      52       43   60     50
#
#    height  weight   BMI
# 0     0.7     6.9  14.1
# 1     1.0    13.0  13.0
# 2     2.0   100.0  25.0
# 3     2.4   155.5  27.0
# 4     0.6     8.5  23.6

# %%
p.head()
# Out:
#             name primaryType secondaryType  hp  attack  defence  spa  speed  \
# 0      Bulbasaur       Grass        Poison  45      49       49   65     65
# 1        Ivysaur       Grass        Poison  60      62       63   80     80
# 2       Venusaur       Grass        Poison  80      82       83  100    100
# 3  Mega Venusaur       Grass        Poison  80     100      123  122    120
# 4     Charmander        Fire           NaN  39      52       43   60     50
#
#    height  weight   BMI  legendary
# 0     0.7     6.9  14.1        0.0
# 1     1.0    13.0  13.0        0.0
# 2     2.0   100.0  25.0        0.0
# 3     2.4   155.5  27.0        0.0
# 4     0.6     8.5  23.6        0.0

# %%
p["legendary"].value_counts()
# Out:
# 0.0    907
# 1.0    125
# Name: legendary, dtype: int64

# %%
#dependent variable = legendary, inde... = speed
x = p[["speed"]]

# %%
y = p[["legendary"]]

# %%
from sklearn.model_selection import train_test_split

# %%
xTrain, xTest, yTrain, yTest =train_test_split(x,y,test_size = 0.3)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()

# %%
dtc.fit(xTrain, yTrain)
# Out:
# DecisionTreeClassifier()

# %%
yPred=dtc.predict(xTest)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(yTest,yPred)
# Out:
# array([[261,  12],
#        [ 30,   7]], dtype=int64)

# %%
(264+3)/(264+10+33+3) # = accuracy
# Out:
# 0.8612903225806452

# %%
poke.head()
# Out:
#             name primaryType secondaryType  hp  attack  defence  spa  speed  \
# 0      Bulbasaur       Grass        Poison  45      49       49   65     65
# 1        Ivysaur       Grass        Poison  60      62       63   80     80
# 2       Venusaur       Grass        Poison  80      82       83  100    100
# 3  Mega Venusaur       Grass        Poison  80     100      123  122    120
# 4     Charmander        Fire           NaN  39      52       43   60     50
#
#    height  weight   BMI
# 0     0.7     6.9  14.1
# 1     1.0    13.0  13.0
# 2     2.0   100.0  25.0
# 3     2.4   155.5  27.0
# 4     0.6     8.5  23.6

# %%
#Regression with decision tree

# %%
x = poke[['defence']]  #x = independent

# %%
y = poke[['attack']]   #y = dependent

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dtr = DecisionTreeRegressor()

# %%
dtr.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = dtr.predict(x_test)

# %%
y_test.head()
# Out:
#      attack
# 118     105
# 955      58
# 533     112
# 46       70
# 952      35

# %%
y_pred[0:5]
# Out:
# array([83.92307692, 62.75      , 42.        , 75.5       , 83.57894737])

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 933.0238819861456

# %%
poke.head()
# Out:
#             name primaryType secondaryType  hp  attack  defence  spa  speed  \
# 0      Bulbasaur       Grass        Poison  45      49       49   65     65
# 1        Ivysaur       Grass        Poison  60      62       63   80     80
# 2       Venusaur       Grass        Poison  80      82       83  100    100
# 3  Mega Venusaur       Grass        Poison  80     100      123  122    120
# 4     Charmander        Fire           NaN  39      52       43   60     50
#
#    height  weight   BMI
# 0     0.7     6.9  14.1
# 1     1.0    13.0  13.0
# 2     2.0   100.0  25.0
# 3     2.4   155.5  27.0
# 4     0.6     8.5  23.6
